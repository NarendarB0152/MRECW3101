# %% [markdown]
# <a href="https://colab.research.google.com/github/NarendarB0152/MRECW3101/blob/master-branch/concepts/narendar_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers = [10, 20, 30, 40]

print(numbers)
# Out:
# [10, 20, 30, 40]
